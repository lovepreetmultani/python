# %% [markdown]
# <a href="https://colab.research.google.com/github/lovepreetmultani/python/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x=np.linspace(0,10,200)
y=x**2

# %%
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
plt.show()

# %%
fig=plt.figure()
axis=fig.add_axes([0.1,0.1,0.8,0.8])
axis.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First plot')

axes[1].plot(y,x)
axes[1].set_title('Second plot')
plt.tight_layout()
#axes.plot(x,y)

# %%
 fig=plt.figure()
 ax=fig.add_axes([0,0,1,1])
 ax.plot(x,y,color='purple',linewidth=3,alpha=0.5)
